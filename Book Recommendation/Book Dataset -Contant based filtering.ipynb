# %%
from datetime import datetime
import os
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

from scipy import sparse
from scipy.sparse import csc_matrix
from sklearn.decomposition import TruncatedSVD

np.random.seed(0)

# %% [markdown]
# ### Book  Dataset
# https://zenodo.org/record/4265096#.YtXPf3ZBy5c

# %%
df = pd.read_csv('books_1.Best_Books_Ever.csv')

df.head(1)
# Out:
#                      bookId             title               series  \
# 0  2767052-the-hunger-games  The Hunger Games  The Hunger Games #1
#
#             author  rating                                        description  \
# 0  Suzanne Collins    4.33  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
#
#   language           isbn                                             genres  \
# 0  English  9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
#
#                                           characters  ... firstPublishDate  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...              NaN
#
#                                               awards numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...    6376780
#
#                                       ratingsByStars likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...         96.0
#
#                                              setting  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
#
#                                             coverImg  bbeScore bbeVotes  price
# 0  https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516   5.09
#
# [1 rows x 25 columns]

# %% [markdown]
# ### EDA on Rating dataset
# - This dataset contain user rating information which will be very handy for recommendation system

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             50131 non-null  object
#  13  publisher         48782 non-null  object
#  14  publishDate       51598 non-null  object
#  15  firstPublishDate  31152 non-null  object
#  16  awards            52478 non-null  object
#  17  numRatings        52478 non-null  int64
#  18  ratingsByStars    52478 non-null  object
#  19  likedPercent      51856 non-null  float64
#  20  setting           52478 non-null  object
#  21  coverImg          51873 non-null  object
#  22  bbeScore          52478 non-null  int64
#  23  bbeVotes          52478 non-null  int64
#  24  price             38113 non-null  object
# dtypes: float64(2), int64(3), object(20)
# memory usage: 10.0+ MB

# %% [markdown]
# ### About dataset
# - This dataset have multiple columns describing details about books.These columns can be used to find similar books.So we can use content based filtering on the dataset.

# %%
df=df[['title','author','description','genres','awards']]
df['description']=df['description'].str.lower()
df.head(5)
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description  \
# 0  winning means fame and fortune.losing means ce...
# 1  there is a door at the end of a silent corrido...
# 2  the unforgettable novel of a childhood in a sl...
# 3  alternate cover edition of isbn 9780679783268s...
# 4  about three things i was absolutely positive.\...
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
#
#                                               awards
# 0  ['Locus Award Nominee for Best Young Adult Boo...
# 1  ['Bram Stoker Award for Works for Young Reader...
# 2  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3                                                 []
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...

# %%
df['tag'] = df['author'] + df['description'] + df['genres'] + df['awards']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        52478 non-null  object
#  1   author       52478 non-null  object
#  2   description  51140 non-null  object
#  3   genres       52478 non-null  object
#  4   awards       52478 non-null  object
#  5   tag          51140 non-null  object
# dtypes: object(6)
# memory usage: 2.4+ MB

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')
vector = cv.fit_transform(df['tag'].values.astype('U')).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity = cosine_similarity(vector)

# %%
def RecommendBook(book,df,similarity):
    index  = df[df['title'] == book].index [0]
    distance = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    result=[]
    for i in distance[1:11]:
        result.append(df.iloc[i[0]].title)
    return result

# %%
df[df["title"]=='Harry Potter and the Prisoner of Azkaban']
# Out:
#                                        title  \
# 93  Harry Potter and the Prisoner of Azkaban
#
#                                        author  \
# 93  J.K. Rowling, Mary GrandPré (Illustrator)
#
#                                           description  \
# 93  harry potter's third year at hogwarts is full ...
#
#                                                genres  \
# 93  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
#
#                                                awards  \
# 93  ['Bram Stoker Award for Best Work for Young Re...
#
#                                                   tag
# 93  J.K. Rowling, Mary GrandPré (Illustrator)harry...

# %%
resuls=RecommendBook('Harry Potter and the Prisoner of Azkaban',df,cosine_similarity)

# %%
results_df=df[df["title"].isin(resuls)]

# %%
results_df
# Out:
#                                           title  \
# 1     Harry Potter and the Order of the Phoenix
# 32        Harry Potter and the Sorcerer's Stone
# 61                                    The Giver
# 103         Harry Potter and the Goblet of Fire
# 113                                      Eragon
# 126     Harry Potter and the Chamber of Secrets
# 138                                       Holes
# 397                          The Amber Spyglass
# 822                           The City of Ember
# 5355       Escape from Mr. Lemoncello's Library
#
#                                          author  \
# 1     J.K. Rowling, Mary GrandPré (Illustrator)
# 32    J.K. Rowling, Mary GrandPré (Illustrator)
# 61                Lois Lowry (Goodreads Author)
# 103   J.K. Rowling, Mary GrandPré (Illustrator)
# 113      Christopher Paolini (Goodreads Author)
# 126   J.K. Rowling, Mary GrandPré (Illustrator)
# 138             Louis Sachar (Goodreads Author)
# 397                              Philip Pullman
# 822                               Jeanne DuPrau
# 5355       Chris Grabenstein (Goodreads Author)
#
#                                             description  \
# 1     there is a door at the end of a silent corrido...
# 32    harry potter's life is miserable. his parents ...
# 61    twelve-year-old jonas lives in a seemingly ide...
# 103   harry potter is midway through his training as...
# 113   an alternate cover edition for isbn 9780375826...
# 126   ever since harry potter had come home for the ...
# 138   stanley yelnats is under a curse. a curse that...
# 397   will is the bearer of the knife. now, accompan...
# 822   an alternate cover edition can be found here.m...
# 5355  a new york times bestsellerkyle keeley is the ...
#
#                                                  genres  \
# 1     ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 32    ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...
# 61    ['Young Adult', 'Fiction', 'Classics', 'Dystop...
# 103   ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 113   ['Fantasy', 'Young Adult', 'Fiction', 'Dragons...
# 126   ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 138   ['Young Adult', 'Fiction', 'Childrens', 'Middl...
# 397   ['Fantasy', 'Young Adult', 'Fiction', 'Science...
# 822   ['Young Adult', 'Dystopia', 'Fantasy', 'Scienc...
# 5355  ['Middle Grade', 'Mystery', 'Fiction', 'Childr...
#
#                                                  awards  \
# 1     ['Bram Stoker Award for Works for Young Reader...
# 32    ["Mythopoeic Fantasy Award for Children's Lite...
# 61    ['Newbery Medal (1994)', "Mythopoeic Fantasy A...
# 103   ['Hugo Award for Best Novel (2001)', "Mythopoe...
# 113   ["Book Sense Book of the Year Award for Childr...
# 126   ["Mythopoeic Fantasy Award for Children's Lite...
# 138   ['Newbery Medal (1999)', "National Book Award ...
# 397   ['Booker Prize Nominee for Longlist (2001)', '...
# 822   ['California Book Award for Young Adult (Silve...
# 5355  ["Anthony Award Nominee for Best Children's or...
#
#                                                     tag
# 1     J.K. Rowling, Mary GrandPré (Illustrator)there...
# 32    J.K. Rowling, Mary GrandPré (Illustrator)harry...
# 61    Lois Lowry (Goodreads Author)twelve-year-old j...
# 103   J.K. Rowling, Mary GrandPré (Illustrator)harry...
# 113   Christopher Paolini (Goodreads Author)an alter...
# 126   J.K. Rowling, Mary GrandPré (Illustrator)ever ...
# 138   Louis Sachar (Goodreads Author)stanley yelnats...
# 397   Philip Pullmanwill is the bearer of the knife....
# 822   Jeanne DuPrauan alternate cover edition can be...
# 5355  Chris Grabenstein (Goodreads Author)a new york...

# %%
from datetime import datetime
import os
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

from scipy import sparse
from scipy.sparse import csc_matrix
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# ## Load Dataset
# ### Spotify   Dataset
#
# Description of dataset https://www.kaggle.com/datasets/zaheenhamidani/ultimate-spotify-tracks-db

# %%
df = pd.read_csv("SpotifyFeatures.csv")

# %%
df.head(1)
# Out:
#    genre     artist_name                   track_name                track_id  \
# 0  Movie  Henri Salvador  C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
#
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0           0         0.611         0.389        99373    0.91
#
#    instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 0               0.0  C#     0.346    -1.828  Major       0.0525  166.969
#
#   time_signature  valence
# 0            4/4    0.814

# %% [markdown]
# ## We are going to check for all the analysis with the target as 'popularity'

# %%
from yellowbrick.target import FeatureCorrelation

feature_names = ['acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence','duration_ms']

X, y = df[feature_names], df['popularity']

# Create a list of the feature names
features = np.array(feature_names)

# Instantiate the visualizer
visualizer = FeatureCorrelation(labels=features)

plt.rcParams['figure.figsize']=(5,5)
visualizer.fit(X, y)     # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB

# %% [markdown]
# ### Observations:
# - Popularity column could be used to filter out few data.
# - Genre columns seems to one important column for giving recommendation
# - atrist_name could be useful as many user choose to listen songs of there favourite artists.
# - we have multiple columns which contain continuous values

# %% [markdown]
# ### First remove rows based on popularity information

# %%
import scipy.stats as st

data = df.loc[:, 'popularity'].values

sns.displot(data=data)


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])


ax.hist(
    data,
    alpha=0.1,
    bins=100,
    density=True
)

ax.axvline(x=50)
plt.xlabel('popularity')
plt.title('popularity distribution')
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.hist(
    data,
    alpha=0.1,
    bins=100,
    density=True,
    cumulative=True
)
ax.axvline(x=50)

plt.xlabel('popularity')
plt.title('cumulative popularity distribution')
plt.show()

# %%
df= df.query('popularity >= 50')
song_df=df
df.head(1)
# Out:
#     genre    artist_name                  track_name                track_id  \
# 135   R&B  Mary J. Blige  Be Without You - Kendu Mix  2YegxR5As7BeQuVp2U6pek
#
#      popularity  acousticness  danceability  duration_ms  energy  \
# 135          65         0.083         0.724       246333   0.689
#
#      instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 135               0.0   D     0.304    -5.922  Minor        0.135  146.496
#
#     time_signature  valence
# 135            4/4    0.693

# %% [markdown]
# ### Analysing all columns with continuous values

# %% [markdown]
# #### Corelation with different columns with column "energy"

# %%
from yellowbrick.target import FeatureCorrelation

feature_names = ['popularity','acousticness', 'danceability', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence','duration_ms']

X, y = df[feature_names], df[ 'energy']

# Create a list of the feature names
features = np.array(feature_names)

# Instantiate the visualizer
visualizer = FeatureCorrelation(labels=features)

plt.rcParams['figure.figsize']=(5,5)
visualizer.fit(X, y)     # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %%
from yellowbrick.target import FeatureCorrelation

feature_names = ['popularity','acousticness', 'danceability', 'instrumentalness',
       'liveness', 'energy', 'speechiness', 'tempo', 'valence','duration_ms']

X, y = df[feature_names], df[ 'loudness']

# Create a list of the feature names
features = np.array(feature_names)

# Instantiate the visualizer
visualizer = FeatureCorrelation(labels=features)

plt.rcParams['figure.figsize']=(5,5)
visualizer.fit(X, y)     # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %% [markdown]
# #### Observations:
# - From above we observe energy has very positive correlation  with loudness and negetive corelation with acousticness.
#   So we will remove these columns

# %% [markdown]
# ### For all information we have from avove we can start applying machine learning algorithms for following:
# - Try to find similar songs using continuous features.We can apply K-Means ,cosine similarities for this
# - Find similar artists.This is helpful to recommend users.
# - best songs from particulr genre.

# %% [markdown]
# ## Task 1: Find similar songs

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# df[['acousticness','danceability','duration_ms','energy',\
#     'instrumentalness','liveness','loudness','speechiness','tempo','valence']] =\
# scaler.fit_transform(df[['acousticness','danceability','duration_ms','energy',\
#     'instrumentalness','liveness','loudness','speechiness','tempo','valence']])

df[['danceability','energy',\
    'instrumentalness','liveness','speechiness','tempo','valence']] =\
scaler.fit_transform(df[['danceability','energy',\
    'instrumentalness','liveness','speechiness','tempo','valence']])

# %%
songs_df=df
songs_df.head(1)
# Out:
#     genre    artist_name                  track_name                track_id  \
# 135   R&B  Mary J. Blige  Be Without You - Kendu Mix  2YegxR5As7BeQuVp2U6pek
#
#      popularity  acousticness  danceability  duration_ms    energy  \
# 135          65     -0.574957      0.711805     0.279707  0.274961
#
#      instrumentalness key  liveness  loudness   mode  speechiness     tempo  \
# 135         -0.298401   D   0.81897  0.396694  Minor     0.298025  0.908694
#
#     time_signature   valence  cluster
# 135            4/4  0.939345       14

# %%
# df_tmp=df[['acousticness','danceability','duration_ms','energy',\
#     'instrumentalness','liveness','loudness','speechiness','tempo','valence']]
# df_tmp.head()
df_tmp=df[['danceability','duration_ms','energy',\
    'instrumentalness','liveness','speechiness','tempo','valence']]
df_tmp.head()
# Out:
#      danceability  duration_ms    energy  instrumentalness  liveness  \
# 135      0.711805     0.279707  0.274961         -0.298401  0.818970
# 136      0.462112    -0.680161 -0.112137         -0.298401 -0.563872
# 137      0.955096    -0.470874 -0.553135         -0.298378 -0.481723
# 138     -0.318979     0.187738 -1.307732         -0.284652 -0.608370
# 139      0.257236    -0.239557 -0.058237         -0.298401 -0.706949
#
#      speechiness     tempo   valence
# 135     0.298025  0.908694  0.939345
# 136    -0.561566 -0.878883 -0.659283
# 137    -0.070911 -1.542193 -1.682405
# 138     0.165925 -1.188704  1.263391
# 139    -0.589873 -0.686034 -0.041435

# %% [markdown]
# ### Find similar songs using continuous features.

# %% [markdown]
# #### Apply K-means
# - We will use Elbow method to find value of hyperparameter K.

# %%
from sklearn.cluster import KMeans

num_clust = 30

wcss = []

for i in range(1, num_clust+1):
    print(f'processing for k={i}')
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df_tmp)
    # inertia method returns wcss for that model
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10,5))

sns.lineplot(range(1, num_clust+1), wcss,marker='o',color='red')

plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# processing for k=1
# processing for k=2
# processing for k=3
# processing for k=4
# processing for k=5
# processing for k=6
# processing for k=7
# processing for k=8
# processing for k=9
# processing for k=10
# processing for k=11
# processing for k=12
# processing for k=13
# processing for k=14
# processing for k=15
# processing for k=16
# processing for k=17
# processing for k=18
# processing for k=19
# processing for k=20
# processing for k=21
# processing for k=22
# processing for k=23
# processing for k=24
# processing for k=25
# processing for k=26
# processing for k=27
# processing for k=28
# processing for k=29
# processing for k=30
# C:\Users\cseka\AppData\Roaming\Python\Python36\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Select k value as 20

# %%
num_clust = 20

kmeans = KMeans(n_clusters = num_clust, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(df_tmp)

df_tmp.loc[:, 'cluster'] = y_kmeans

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.hist(
    y_kmeans,
    bins=num_clust,
    density=True,
    alpha=0.8
)

plt.title('Distribution by cluster')
plt.show()
# Out:
# C:\Users\cseka\AppData\Roaming\Python\Python36\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df_tmp.head(1)
# Out:
#      danceability  duration_ms    energy  instrumentalness  liveness  \
# 135      0.711805     0.279707  0.274961         -0.298401   0.81897
#
#      speechiness     tempo   valence  cluster
# 135     0.298025  0.908694  0.939345        7

# %%
df['cluster']=df_tmp['cluster']

# %% [markdown]
# #### Now lets find similarity of a song

# %%
songs_df=df[(df['artist_name']=='Ed Sheeran' )& (df['track_name']=='Perfect')]
songs_df=songs_df.head(1)
songs_df
# Out:
#        genre artist_name track_name                track_id  popularity  \
# 107888   Pop  Ed Sheeran    Perfect  0tgVpDi06FyKpA1z0VMD4v          89
#
#         acousticness  danceability  duration_ms    energy  instrumentalness  \
# 107888     -0.280838     -0.088493     0.553353 -0.905934         -0.298401
#
#        key  liveness  loudness   mode  speechiness     tempo time_signature  \
# 107888  G# -0.536489  0.286172  Major    -0.756885 -0.856038            3/4
#
#          valence  cluster
# 107888 -1.328979        5

# %%
cluster_df=df[(df['cluster']==3) & (df['genre']=='Pop')].sort_values('popularity', ascending=[False])

# %%
cluster_df.head(1)
# Out:
#        genre  artist_name track_name                track_id  popularity  \
# 107803   Pop  Post Malone       Wow.  6MWtB6iiXyIwun0YzU6DFP          99
#
#         acousticness  danceability  duration_ms    energy  instrumentalness  \
# 107803     -0.280838      1.409666    -1.272554 -0.460036         -0.298389
#
#        key  liveness  loudness   mode  speechiness     tempo time_signature  \
# 107803   B -0.570718 -0.021872  Minor     0.703759 -0.688058            4/4
#
#          valence  cluster
# 107803 -0.391405        3

# %%
cluster_df[cluster_df['artist_name']=='Ed Sheeran']
# Out:
# Empty DataFrame
# Columns: [genre, artist_name, track_name, track_id, popularity, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, time_signature, valence, cluster]
# Index: []

# %%
features_df=cluster_df[['acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence']]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(features_df)

# %%
def recommend(artist,song):
    genre=df[(df['artist_name']==artist )& (df['track_name']==song)]['genre']
    cluster=df[(df['artist_name']==artist )& (df['track_name']==song)]['cluster']
    cluster=cluster.values[0]
    genre=genre.values[0]
    cluster_df=df[(df['cluster']==cluster) & (df['genre']==genre)].sort_values('popularity', ascending=[False])
    cluster_df.reset_index(inplace=True)
    cluster_df['index']=np.arange(len(cluster_df))
    index  =cluster_df[(cluster_df['artist_name']==artist )& (cluster_df['track_name']==song)]['index']
    index=index.values[0]
    #index
    features_df=cluster_df[['acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence']]
    similarity = cosine_similarity(features_df)
    distance = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    result=[]
    for i in distance[0:10]:
        result.append(i[0])
    return cluster_df[cluster_df['index'] .isin(result)]

# %%
recommend('Ed Sheeran','Perfect')
# Out:
#      index genre   artist_name                       track_name  \
# 0        0   Pop    Ed Sheeran                          Perfect
# 22      22   Pop   Alicia Keys                           No One
# 68      68   Pop      Ella Mai  She Don't (feat. Ty Dolla $Ign)
# 97      97   Pop          Lauv                 Getting Over You
# 176    176   Pop    The Weeknd                        Shameless
# 318    318   Pop     Rico Love                    Fight for You
# 445    445   Pop         Lorde                          400 Lux
# 484    484   Pop         Drake                    Now & Forever
# 505    505   Pop      Labrinth           Beneath Your Beautiful
# 622    622   Pop  Taylor Swift                    The Last Time
#
#                    track_id  popularity  acousticness  danceability  \
# 0    0tgVpDi06FyKpA1z0VMD4v          89     -0.280838     -0.088493
# 22   6IwKcFdiRQZOWeYNhUiWIv          80     -0.803268      0.199614
# 68   01JPQ87UHeGysPVwTqMJHK          75      0.105193      0.238029
# 97   4G4gtvlaFaI6v6wWD8UvqL          73      0.123576     -0.056481
# 176  6C6fHTuFUxVtJpBOOaMvJr          68     -0.343339     -0.062884
# 318  479acVfQ74icOy772hE1ba          65     -0.602164     -0.517453
# 445  6rjtB7KSIiJ6v9vrACMlqF          62     -0.574957      0.065164
# 484  4zLOwx1yRJXWkHKt1XzF1p          61     -0.394809     -0.242151
# 505  1wVcLKdJ4AFKPhKucNvEpy          60     -0.041866     -0.350991
# 622  7vvIpJZye5cRR6De1LKM0m          54     -0.744811     -0.722330
#
#      duration_ms    energy  instrumentalness key  liveness  loudness   mode  \
# 0       0.553353 -0.905934         -0.298401  G# -0.536489  0.286172  Major
# 22      0.399639 -0.415936         -0.298352  C# -0.344808  0.540089  Minor
# 68      0.564544 -0.758935         -0.298401   G -0.050441 -0.053895  Minor
# 97      0.432876 -0.616835         -0.298388   C -0.616585 -0.171785  Major
# 176     0.394732 -0.347336         -0.298401  F# -0.515952 -0.280324  Major
# 318     0.063558 -0.783434         -0.298356   G -0.502261  0.393294  Major
# 445     0.086550 -0.749135         -0.287085   G -0.413266 -0.297610  Major
# 484     0.840675 -0.577635         -0.298401  F# -0.563872 -0.000901  Major
# 505     0.688243 -0.543335         -0.298401   D -0.550181  0.415115  Major
# 622     1.112813 -0.856934         -0.298369   D -0.648075  0.081848  Major
#
#      speechiness     tempo time_signature   valence  cluster
# 0      -0.756885 -0.856038            3/4 -1.328979        5
# 22     -0.705932 -1.027825            4/4 -1.337620        5
# 68     -0.504009 -0.686960            4/4 -1.419711        5
# 97     -0.615350 -0.961209            4/4 -1.562292        5
# 176    -0.723860 -0.684936            4/4 -1.000612        5
# 318    -0.562510 -0.680477            4/4 -1.333299        5
# 445    -0.713481 -0.960420            4/4 -1.272811        5
# 484    -0.670077 -0.413705            4/4 -1.646112        5
# 505    -0.636108 -1.235870            4/4 -1.069742        5
# 622    -0.721973 -0.892501            4/4 -1.484521        5
